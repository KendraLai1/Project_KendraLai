# %% [markdown]
# <a href="https://colab.research.google.com/github/KendraLai1/Project_KendraLai/blob/main/Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my project assignment.")
# Out:
# Hello, GitHub! This is my project assignment.
